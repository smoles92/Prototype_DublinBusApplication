# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import datetime
from datetime import datetime as dt
import time

# %matplotlib inline

# %%
# Read dataset into the notebook
df = pd.read_csv('siri.20121106.csv')
# Out:
# C:\Users\minogud2\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print("Number of rows and columns: ", df.shape)
# Out:
# Number of rows and columns:  (1765912, 15)

# %%
df.head(1)
# Out:
#           Timestamp LineID  Direction JourneyPatternID   TimeFrame  \
# 0  1352160000000000     15          0         00150001  2012-11-05
#
#    VehicleJourneyID Operator  Congestion       Lon        Lat  Delay  BlockID  \
# 0              5826       RD           0 -6.258584  53.340099   -361    15013
#
#    VehicleID StopID  AtStop
# 0      33210   4870       0

# %%
# alter format to readable datetime
df['Timestamp'] = pd.to_datetime(df['Timestamp'], format='%Y%m%d %H:%M:%S.%f')

# %%
df.head(50)
# Out:
#                  Timestamp LineID  Direction JourneyPatternID   TimeFrame  \
# 0  1970-01-16 15:36:00.000     15          0         00150001  2012-11-05
# 1  1970-01-16 15:36:00.000     46          0         046A1002  2012-11-05
# 2  1970-01-16 15:36:00.000     14          0         00140001  2012-11-05
# 3  1970-01-16 15:36:00.002     41          0         041B0002  2012-11-05
# 4  1970-01-16 15:36:00.002     63          0             null  2012-11-05
# 5  1970-01-16 15:36:00.002     39          0         039A1002  2012-11-05
# 6  1970-01-16 15:36:00.002     65          0         00650001  2012-11-05
# 7  1970-01-16 15:36:00.002     40          0         040D1001  2012-11-05
# 8  1970-01-16 15:36:00.002      4          0             null  2012-11-05
# 9  1970-01-16 15:36:00.002     11          0         00111002  2012-11-05
# 10 1970-01-16 15:36:00.002     31          0         00311001  2012-11-05
# 11 1970-01-16 15:36:00.002     27          0         00270001  2012-11-05
# ...

# %%
group = df.groupby(['JourneyPatternID'])

test_group = group.get_group(('046A1002'))

#Check how many there are
test_group
# Out:
#                       Timestamp LineID  Direction JourneyPatternID  \
# 1       1970-01-16 15:36:00.000     46          0         046A1002
# 316     1970-01-16 15:36:00.039     46          0         046A1002
# 489     1970-01-16 15:36:00.059     46          0         046A1002
# 632     1970-01-16 15:36:00.079     46          0         046A1002
# 788     1970-01-16 15:36:00.098     46          0         046A1002
# 812     1970-01-16 15:36:00.100     46          0         046A1002
# 959     1970-01-16 15:36:00.120     46          0         046A1002
# 1088    1970-01-16 15:36:00.138     46          0         046A1002
# 1239    1970-01-16 15:36:00.158     46          0         046A1002
# 1387    1970-01-16 15:36:00.179     46          0         046A1002
# 1515    1970-01-16 15:36:00.199     46          0         046A1002
# 1664    1970-01-16 15:36:00.217     46          0         046A1002
# 1689    1970-01-16 15:36:00.219     46          0         046A1002
# ...

# %%
# Save cleaned dataframe to new CSV file
test_group.to_csv('46a.csv', index=False)

# %%
test_group.head(5)
# Out:
#                   Timestamp LineID  Direction JourneyPatternID   TimeFrame  \
# 1   1970-01-16 15:36:00.000     46          0         046A1002  2012-11-05
# 316 1970-01-16 15:36:00.039     46          0         046A1002  2012-11-05
# 489 1970-01-16 15:36:00.059     46          0         046A1002  2012-11-05
# 632 1970-01-16 15:36:00.079     46          0         046A1002  2012-11-05
# 788 1970-01-16 15:36:00.098     46          0         046A1002  2012-11-05
#
#      VehicleJourneyID Operator  Congestion       Lon        Lat  Delay  \
# 1                7267       D2           0 -6.259093  53.345425  -1101
# 316              7267       D2           0 -6.255533  53.346035  -1043
# 489              7267       D2           0 -6.255517  53.346035  -1043
# 632              7267       D2           0 -6.252850  53.345901  -1043
# 788              7267       D2           0 -6.252850  53.345901   -983
#
#      BlockID  VehicleID StopID  AtStop
# 1      46004      36024    794       0
# ...

# %%
# Read dataset into the notebook
df2 = pd.read_csv("stops.txt", header='infer', sep=",")

# %%
df2.head(5)
# Out:
#        ﻿stop_id       stop_name   stop_lat  stop_lon
# 0  8220DB000002  Parnell Square  53.352244 -6.263693
# 1  8220DB000003  Parnell Square  53.352308 -6.263781
# 2  8220DB000004  Parnell Square  53.352565 -6.264161
# 3  8220DB000006  Parnell Square  53.352740 -6.264439
# 4  8220DB000007  Parnell Square  53.352832 -6.264556

# %%
# Read dataset into the notebook
df3 = pd.read_csv("stop_times.txt", header='infer', sep=",")

# %%
df3.head(5)
# Out:
#                    ﻿trip_id arrival_time departure_time       stop_id  \
# 0  1.1598.0-33A-b12-1.451.I     16:15:00       16:15:00  8240DB003813
# 1  1.1598.0-33A-b12-1.451.I     16:15:39       16:15:39  8240DB003814
# 2  1.1598.0-33A-b12-1.451.I     16:17:11       16:17:11  8240DB003815
# 3  1.1598.0-33A-b12-1.451.I     16:17:22       16:17:22  8240DB003816
# 4  1.1598.0-33A-b12-1.451.I     16:17:44       16:17:44  8240DB003566
#
#    stop_sequence stop_headsign  pickup_type  drop_off_type  \
# 0              1        Swords            0              0
# 1              2        Swords            0              0
# 2              3        Swords            0              0
# 3              4        Swords            0              0
# 4              5        Swords            0              0
#
#    shape_dist_traveled
# 0             0.000000
# 1           827.070328
# 2          2746.649492
# 3          2973.900755
# 4          3447.155571

# %%
df3['is46A'] = df3['﻿trip_id'].str.contains('46A', na=False)

# test_group3 = group3.str.contains('12564.3514.0-46A-b12-1', na=False)

# %%
df3.head(5)
# Out:
#                    ﻿trip_id arrival_time departure_time       stop_id  \
# 0  1.1598.0-33A-b12-1.451.I     16:15:00       16:15:00  8240DB003813
# 1  1.1598.0-33A-b12-1.451.I     16:15:39       16:15:39  8240DB003814
# 2  1.1598.0-33A-b12-1.451.I     16:17:11       16:17:11  8240DB003815
# 3  1.1598.0-33A-b12-1.451.I     16:17:22       16:17:22  8240DB003816
# 4  1.1598.0-33A-b12-1.451.I     16:17:44       16:17:44  8240DB003566
#
#    stop_sequence stop_headsign  pickup_type  drop_off_type  \
# 0              1        Swords            0              0
# 1              2        Swords            0              0
# 2              3        Swords            0              0
# 3              4        Swords            0              0
# 4              5        Swords            0              0
#
#    shape_dist_traveled  is46A
# 0             0.000000  False
# 1           827.070328  False
# 2          2746.649492  False
# 3          2973.900755  False
# 4          3447.155571  False

# %%
group3 = df3.groupby(['is46A'])

test_group3 = group3.get_group((True))

# %%
test_group3
# Out:
#                             ﻿trip_id arrival_time departure_time  \
# 170829  12564.3514.0-46A-b12-1.308.O     07:00:00       07:00:00
# 170830  12564.3514.0-46A-b12-1.308.O     07:01:03       07:01:03
# 170831  12564.3514.0-46A-b12-1.308.O     07:01:36       07:01:36
# 170832  12564.3514.0-46A-b12-1.308.O     07:02:28       07:02:28
# 170833  12564.3514.0-46A-b12-1.308.O     07:03:00       07:03:00
# 170834  12564.3514.0-46A-b12-1.308.O     07:03:28       07:03:28
# 170835  12564.3514.0-46A-b12-1.308.O     07:04:00       07:04:00
# 170836  12564.3514.0-46A-b12-1.308.O     07:05:00       07:05:00
# 170837  12564.3514.0-46A-b12-1.308.O     07:06:14       07:06:14
# 170838  12564.3514.0-46A-b12-1.308.O     07:07:24       07:07:24
# 170839  12564.3514.0-46A-b12-1.308.O     07:08:00       07:08:00
# 170840  12564.3514.0-46A-b12-1.308.O     07:09:00       07:09:00
# 170841  12564.3514.0-46A-b12-1.308.O     07:11:01       07:11:01
# ...

# %%
# Save cleaned dataframe to new CSV file
test_group3.to_csv('46a_stoptimes.csv', index=False)

# %%
# Read dataset into the notebook
df46A = pd.read_csv('46a.csv')

# %%
# Read dataset into the notebook
df46AStops = pd.read_csv('46a_stoptimes.csv')

# %%
df46A.head(5)
# Out:
#                  Timestamp  LineID  Direction JourneyPatternID   TimeFrame  \
# 0  1970-01-16 15:36:00.000      46          0         046A1002  2012-11-05
# 1  1970-01-16 15:36:00.039      46          0         046A1002  2012-11-05
# 2  1970-01-16 15:36:00.059      46          0         046A1002  2012-11-05
# 3  1970-01-16 15:36:00.079      46          0         046A1002  2012-11-05
# 4  1970-01-16 15:36:00.098      46          0         046A1002  2012-11-05
#
#    VehicleJourneyID Operator  Congestion       Lon        Lat  Delay  BlockID  \
# 0              7267       D2           0 -6.259093  53.345425  -1101    46004
# 1              7267       D2           0 -6.255533  53.346035  -1043    46004
# 2              7267       D2           0 -6.255517  53.346035  -1043    46004
# 3              7267       D2           0 -6.252850  53.345901  -1043    46004
# 4              7267       D2           0 -6.252850  53.345901   -983    46004
#
#    VehicleID  StopID  AtStop
# ...

# %%
df46AStops.head(5)
# Out:
#                        ?trip_id arrival_time departure_time       stop_id  \
# 0  12564.3514.0-46A-b12-1.308.O     07:00:00       07:00:00  8220DB000807
# 1  12564.3514.0-46A-b12-1.308.O     07:01:03       07:01:03  8220DB000808
# 2  12564.3514.0-46A-b12-1.308.O     07:01:36       07:01:36  8220DB000809
# 3  12564.3514.0-46A-b12-1.308.O     07:02:28       07:02:28  8220DB000810
# 4  12564.3514.0-46A-b12-1.308.O     07:03:00       07:03:00  8220DB000811
#
#    stop_sequence  stop_headsign  pickup_type  drop_off_type  \
# 0              1  Dun Laoghaire            0              0
# 1              2  Dun Laoghaire            0              0
# 2              3  Dun Laoghaire            0              0
# 3              4  Dun Laoghaire            0              0
# 4              5  Dun Laoghaire            0              0
#
#    shape_dist_traveled is46A
# 0             0.000000  True
# 1           343.962310  True
# 2           535.012042  True
# 3           841.908087  True
# ...
